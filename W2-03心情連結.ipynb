# %%
from IPython.display import display,YouTubeVideo

# %%
L=["blue","happy","ok"]
i=input("你今天的心情如何? (blue/happy /ok)")
y1=YouTubeVideo('5eXkJ00uBi0') 
y2=YouTubeVideo('bYM1I8XPGaE') 
y3=YouTubeVideo('iE0l8Tx62DE')
y4=YouTubeVideo('29tEEaTN_Sc')
for m in L:
    if i == "blue":
        display(y1)
        break
    elif i == "happy":
        display(y2)
        break
    elif i == "ok":
        display(y3)
        break
else:
    yi=YouTubeVideo('Zd9jkbUHUPc')
    display(y4)
# Out:
# 你今天的心情如何? (blue/happy /ok)ok
